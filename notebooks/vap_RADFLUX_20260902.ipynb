# %% [markdown]
# # just the radflux

# %%
import armbnfmentorer.vaps.bnfradsys43m60sS10c1 as bnfvap43
plt.rcParams['figure.dpi'] = 230

# %%
path_in = '/Volumes/stu3data2/bnf_radsys_data/bnfradsys43m60sS10.b1/'#'/Users/htelg/data/arm/archive/bnf/bnfradsys43m60sS10.b1/'
# path_out = '~/tmp/bnfradsys43m60sS10.c1/{version}/'#'/Users/htelg/data/arm/vap/bnfradsys43m60sS10.c1/{version}/'
radflux_parameters_db = 'bnfvap.db'
reporter = None

# %%
reload(bnfvap43)
reload(bnfvap43.prowo)
reload(bnfvap43.atmbrad)
# Out:
# <module 'atmPy.radiation.retrievals.broadband_shortwave_radiation' from '/Users/htelg/prog/atm-py/atmPy/radiation/retrievals/broadband_shortwave_radiation.py'>

# %%
vapi = bnfvap43.BnfRadsys43m60sS10C1Radflux(p2fld_in = path_in,
                                             # p2fld_out = path_out, 
                                             date_from_name = lambda name: pd.to_datetime(name.split('.')[2]),
                                             output_file_format = 'bnfradsys43m60sS10.c1.{date}.nc',
                                             radflux_parameters_db = 'bnfvap.db', 
                                            verbose = True)
self = vapi
# Out:
# start time: 2026-08-28 14:38:51.433549

# %%
self.combine_masterplan_duplicates()
self.masterplan
self.workplan
# Out:
# Get all files in /Volumes/stu3data2/bnf_radsys_data/bnfradsys43m60sS10.b1 with glob pattern: *.nc
# Warning: Database bnfvap.db table radflux_parameters is empty.
#                                                        p2f_in
# 2025-01-30  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-02-26  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-12  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-13  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-14  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# ...                                                       ...
# 2026-08-22  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-08-23  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-08-24  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-08-25  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-08-26  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
#
# [490 rows x 1 columns]

# %%
row = self.workplan.loc['2026-05-14']

out = self.process_row(row = row,
                        # iloc = 0, 
                       save = False)
# Out:
# No previous optimized clearsky parameters found for 2026-05-14T00:00:00.
# No previous optimized clearsky parameters found, using default parameters.
# nsw_exp attribute is not set, using default
# /Users/htelg/prog/armbnfmentorer/armbnfmentorer/vaps/bnfradsys43m60sS10c1.py:111: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds_wholeday = xr.concat(dslist, dim = 'datetime')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 row = self.workplan.loc['2026-05-14']
#       2
# ----> 3 out = self.process_row(row = row,
#       4                         # iloc = 0,
#       5                        save = False)
#
# File ~/prog/armbnfmentorer/armbnfmentorer/vaps/bnfradsys43m60sS10c1.py:143, in BnfRadsys43m60sS10C1Radflux.process_row(self, row, iloc, loc, save)
#     141     else:
#     142         bbi.clearsky_parameters = clearsky_parameters_previous #set starting conditions
# --> 143     bbi.optimize_clearsky_parameters()
#     144 # min_required_points = 2
#     145 # file_too_short = False
#     146 # if bbi.dataset.datetime.shape[0] < min_required_points:
#    (...)    151 # if not file_too_short and not file_too_long:
#     152     # bbi.optimize_clearsky_parameters()
#     154 current_clearsky_parameters = bbi.clearsky_parameters
#
# File ~/prog/atm-py/atmPy/radiation/retrievals/broadband_shortwave_radiation.py:580, in CombinedGlobalDiffuseDirect.optimize_clearsky_parameters(self, n_iterations, min_clear_for_update_equivalent)
#     578 self.dataset.attrs['clear_sky_params_optimized'] = 'Failed'
#     579 if self.verbose:
# --> 580     print((f'Original values -- nsw_exp:{self.get_attr('nsw_exp'):0.3f},' #normalized_total_shortwave_power_exponent
#     581         f'nsw_min: {self.get_attr('nsw_min'):0.1f},'
#     582         f'nsw_max: {self.get_attr('nsw_max'):0.1f},'
#     583         f'ndr_exp: {self.get_attr('ndr_exp'):0.3f}'))
#     585 for it in range(n_iterations):
#     586     # 1 clear sky
#     587     n_clear = int(self.mask_clear_sky_radflux.sum())
#
# File ~/prog/atm-py/atmPy/radiation/retrievals/broadband_shortwave_radiation.py:113, in SolarIrradiation.get_attr(self, attr)
#     111     if self.verbose:
#     112         print(f'{attr} attribute is not set, using default')
# --> 113     self.dataset.attrs[attr] = default_config[attr]
#     114 return self.dataset.attrs[attr]
#
# NameError: name 'default_config' is not defined

# %%
ds = out.dataset.compute()

# %%
f,aa = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})
a = aa[0]
out.plot_overview(show_clearsky=True, apply_mask_clear_sky = True, ax = a)
a.set_ylim(-10, 1300)

a.legend(loc = 6, fontsize = 'xx-small')
#################
# f,a = plt.subplots()
a = aa[1]
dx = 0.01

varlist = [var for var in ds if 'mask_' in var]
for e,var in enumerate(varlist):
    da = ds[var]
    (da + (e*dx)).plot(ax = a, 
                       label = var,
                      )
    # break
a.legend(loc = 6, fontsize = 'xx-small')

# %%
da.long_name
# Out:
# ('clear sky classification mask',)

# %%
self.process(raise_errors=True)
# Out:
# We have to wait for the next day to to finish this local day.
# .

# %% [markdown]
# # check the radflux parameters

# %%
df = self.radflux_db.dump_radflux_parameters()

# %%
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )

# %%
df.dropna()
# Out:
#                                                    input_file  \
# 2026-05-14  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-05-12  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-05-04  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-05-03  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2026-04-19  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# ...                                                       ...
# 2025-03-23  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-22  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-21  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-18  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
# 2025-03-17  /Volumes/stu3data2/bnf_radsys_data/bnfradsys43...
#
#             next_day_needed                processed_at process_version  \
# 2026-05-14                1  2026-07-15T13:42:55.541768             0.1
# 2026-05-12                1  2026-07-15T13:42:55.230985             0.1
# 2026-05-04                1  2026-07-15T13:42:54.025897             0.1
# 2026-05-03                1  2026-07-15T13:42:53.852024             0.1
# 2026-04-19                1  2026-07-15T13:42:50.830712             0.1
# ...                     ...                         ...             ...
# 2025-03-23                1  2026-07-15T13:41:59.699798             0.1
# 2025-03-22                1  2026-07-15T13:41:59.527728             0.1
# 2025-03-21                1  2026-07-15T13:41:59.377495             0.1
# 2025-03-18                0  2026-07-15T13:41:58.913301             0.1
# 2025-03-17                0  2026-07-15T13:37:18.977847             0.1
#
#                  processing_server clear_sky_params_optimized   nsw_exp  \
# 2026-05-14  telg-mbp.cmdl.noaa.gov                       True  1.157392
# 2026-05-12  telg-mbp.cmdl.noaa.gov                       True  1.095200
# 2026-05-04  telg-mbp.cmdl.noaa.gov                       True  1.140858
# 2026-05-03  telg-mbp.cmdl.noaa.gov                       True  1.174942
# 2026-04-19  telg-mbp.cmdl.noaa.gov                       True  1.190689
# ...                            ...                        ...       ...
# 2025-03-23  telg-mbp.cmdl.noaa.gov                       True  1.235715
# 2025-03-22  telg-mbp.cmdl.noaa.gov                       True  1.190711
# 2025-03-21  telg-mbp.cmdl.noaa.gov                       True  1.199695
# 2025-03-18  telg-mbp.cmdl.noaa.gov                       True  1.184232
# 2025-03-17  telg-mbp.cmdl.noaa.gov                       True  1.196250
#
#                 nsw_min      nsw_max   ndr_exp  ...  diffuse_max_exp  \
# 2026-05-14  1066.843736  1119.698208 -0.903453  ...              0.5
# 2026-05-12  1042.724218  1075.919669 -1.527102  ...              0.5
# 2026-05-04  1051.690617  1102.764307 -1.026140  ...              0.5
# 2026-05-03  1075.076248  1139.052175 -0.758809  ...              0.5
# 2026-04-19  1119.657390  1177.968336 -0.656720  ...              0.5
# ...                 ...          ...       ...  ...              ...
# 2025-03-23  1065.326760  1178.956533 -0.323334  ...              0.5
# 2025-03-22  1065.269942  1245.194781 -0.628281  ...              0.5
# 2025-03-21  1160.151069  1231.408872 -0.572629  ...              0.5
# 2025-03-18  1138.424512  1200.764043 -0.721578  ...              0.5
# 2025-03-17  1152.123705  1226.561270 -0.666970  ...              0.5
#
#             max_dsw_dt  ndr_std_max  ndr_window    nsw_coeff    nsw_r2  \
# 2026-05-14        75.0        0.005        11.0  1092.502631  0.999505
# 2026-05-12        75.0        0.005        11.0  1059.846147  0.999361
# 2026-05-04        75.0        0.005        11.0  1078.884252  0.997361
# 2026-05-03        75.0        0.005        11.0  1107.152557  0.999440
# 2026-04-19        75.0        0.005        11.0  1148.340298  0.999719
# ...                ...          ...         ...          ...       ...
# 2025-03-23        75.0        0.005        11.0  1121.463650  0.999072
# 2025-03-22        75.0        0.005        11.0  1155.405605  0.998932
# 2025-03-21        75.0        0.005        11.0  1194.043661  0.999725
# 2025-03-18        75.0        0.005        11.0  1168.613569  0.999555
# 2025-03-17        75.0        0.005        11.0  1191.008616  0.999728
#
#             ndr_std_max_estimated  normalized_diffuse_fit_exp  \
# 2026-05-14               0.003779                    0.259245
# 2026-05-12               0.002577                   -0.445910
# 2026-05-04               0.003849                    0.114729
# 2026-05-03               0.002866                    0.417127
# 2026-04-19               0.002125                    0.520967
# ...                           ...                         ...
# 2025-03-23               0.005547                    0.856913
# 2025-03-22               0.002517                    0.555427
# 2025-03-21               0.002652                    0.627064
# 2025-03-18               0.003616                    0.462655
# 2025-03-17               0.002386                    0.530009
#
#             normalized_diffuse_fit_coeff  max_dsw_dt_estimated
# 2026-05-14                     76.054698              6.881960
# 2026-05-12                     74.350694              8.134864
# 2026-05-04                     96.408227              8.617167
# 2026-05-03                     92.051773              7.368425
# 2026-04-19                    105.745575              9.713249
# ...                                  ...                   ...
# 2025-03-23                    161.220809              9.651587
# 2025-03-22                    102.554176              7.662941
# 2025-03-21                     93.242479              6.908359
# 2025-03-18                     85.183196              9.799199
# 2025-03-17                     83.431958              7.827943
#
# [127 rows x 22 columns]

# %%
for c in df.columns:
    print(c)
# Out:
# input_file
# next_day_needed
# processed_at
# process_version
# processing_server
# clear_sky_params_optimized
# nsw_exp
# nsw_min
# nsw_max
# ndr_exp
# mu0_min
# diffuse_max_coeff
# diffuse_max_exp
# max_dsw_dt
# ndr_std_max
# ndr_window
# nsw_coeff
# nsw_r2
# ndr_std_max_estimated
# normalized_diffuse_fit_exp
# normalized_diffuse_fit_coeff
# max_dsw_dt_estimated

# %%
df.diffuse_max_coeff.plot()
# Out:
# <Axes: >

# %%
df.normalized_diffuse_fit_coeff.plot(ls= '', marker = '.')
# Out:
# <Axes: >

# %%
df.normalized_diffuse_fit_coeff.hist()
# Out:
# <Axes: >

# %%
[c for c in df.columns if 'nsw' in c]
# Out:
# ['nsw_exp', 'nsw_min', 'nsw_max', 'nsw_coeff', 'nsw_r2']

# %%
plt.rcParams['figure.dpi']= 200

# %%
f,aa = plt.subplots(3, sharex=True, gridspec_kw={'hspace' : 0})
########
a = aa[0]
df.nsw_exp.plot(ls = '', marker ='.', ax = a)

##########
a = aa[1]
df.nsw_coeff.plot(ls = '', marker ='.', ax = a)

#########

a = aa[2]
df.nsw_r2.plot(ls = '', marker ='.', ax = a)


# f.autofmt_xdate()
# Out:
# <Axes: >
